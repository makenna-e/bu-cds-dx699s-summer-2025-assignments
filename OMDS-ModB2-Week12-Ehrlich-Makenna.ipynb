# %% [markdown]
# # Week 12 - Milestone Two week

# %% [markdown]
# # 1. Lesson: no lesson this week.  Milestone Two is due!

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Suppose you plot the number visitors to a museum over the seven days of a week; then again the following week.  Can you suggest the advantages and disadvantages of the following two ways of presenting the data?

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
time_series_0 = np.array([100, 110, 130, 120, 100, 90, 80])
time_series_1 = np.array([70, 90, 100, 100, 120, 110, 90])
fig, axs = plt.subplots(1, 2)
axs[0].plot(time_series_0)
axs[1].plot(time_series_1)
plt.subplots_adjust(wspace = 0)
plt.xlabel("Day of the week")
plt.ylabel("Number of visitors")
# Out:
# Text(0, 0.5, 'Number of visitors')

# %%
plt.plot(time_series_0)
plt.plot(time_series_1)
plt.xlabel("Day of the week")
plt.ylabel("Number of visitors")
# Out:
# Text(0, 0.5, 'Number of visitors')

# %% [markdown]
# An advantage of the data plotted separately is that the variation in shape is immediately clear. A disadvantage of the chart is that they have two different axes, which could potentially be misleading or confusing.
#
# An advantage of the data plotted together on one chart is that you can see where data points intersect and you have consistent axes.

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you can work on Milestone Two rather than having a particular exercise about working on your datasets

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 187-205 of the Storytelling With Data book as best you can. (Chapter Eight). You do not have to get the exact data values right, just the overall look and feel.

# %%
df_fraud = pd.read_csv("Fraud_Detection_Data_Train_sampled.csv")

# %%
df_fraud.head()
# Out:
#         id trans_date_trans_time            cc_num  \
# 0  1045211   2020-03-09 15:09:26      577588686219
# 1   547406   2019-08-22 15:49:01    30376238035123
# 2   110142   2019-03-04 01:34:16  4658490815480264
# 3  1285953   2020-06-16 20:04:38  3514897282719543
# 4   271705   2019-05-14 05:54:48  6011381817520024
#
#                                       merchant        category     amt  \
# 0                              fraud_Towne LLC        misc_pos  194.51
# 1                            fraud_Friesen Ltd  health_fitness   52.32
# 2                               fraud_Mohr Inc    shopping_pos    6.53
# 3                      fraud_Gaylord-Powlowski            home    7.33
# 4  fraud_Christiansen, Goyette and Schamberger   gas_transport   64.29
#
#      first        last gender                        street  ...      lat  \
# 0    James  Strickland      M            25454 Leonard Lake  ...  40.6153
# 1  Cynthia       Davis      F            7177 Steven Forges  ...  42.8250
# ...

# %%
# Group by category and fraud status
transactions_by_fraud = df_fraud.groupby(['category', 'is_fraud']).size().unstack(fill_value=0)

# Plot grouped bar chart
transactions_by_fraud.plot(kind='bar', figsize=(12, 8))

# Labels and title
plt.title('Number of Fraudulent vs Non-Fraudulent Transactions by Category')
plt.xlabel('Category')
plt.ylabel('Number of Transactions')
plt.legend(title='Fraud Status', labels=['Non-Fraudulent', 'Fraudulent'], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Layout / plot
plt.tight_layout()
plt.show()

# %%
# Filter to only fraudulent transactions
fraud_transactions = df_fraud[df_fraud['is_fraud'] == 1]

# Group by category (only fraud)
transactions_by_fraud = fraud_transactions.groupby('category').size()

# Plot bar chart for fraudulent transactions only
transactions_by_fraud.plot(kind='bar', figsize=(12, 8))

# Labels and title
plt.title('Number of Fraudulent Transactions by Category')
plt.xlabel('Category')
plt.ylabel('Number of Fraudulent Transactions')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Layout / plot
plt.tight_layout()
plt.show()

# %%
# Group by state and fraud status
transactions_by_fraud = df_fraud.groupby(['state', 'is_fraud']).size().unstack(fill_value=0)

# Group by state (only fraud) and count transactions
fraud_by_state = fraud_transactions.groupby('state').size().sort_values(ascending=False).head(10)

# Plot grouped bar chart
fraud_by_state.plot(kind='bar', figsize=(12, 8))

# Labels
plt.title('Top 10 States with Most Fraudulent Transactions')
plt.xlabel('State')
plt.ylabel('Number of Transactions')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Layout / plot
plt.tight_layout()
plt.show()

# %%
# Convert transaction date to datetime
df_fraud['trans_date_trans_time'] = pd.to_datetime(df_fraud['trans_date_trans_time'])

# Extract year for grouping
df_fraud['year'] = df_fraud['trans_date_trans_time'].dt.year

# Group by category and fraud status
transactions_per_year = df_fraud.groupby(['category', 'year']).size().unstack(fill_value=0)

# Plot grouped bar chart
transactions_per_year.plot(kind='bar', figsize=(12, 8))


# Labels and title
plt.title('Number of Transactions Per Year by Category')
plt.xlabel('Category')
plt.ylabel('Number of Transactions')
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Layout / plot
plt.tight_layout()
plt.show()

# %% [markdown]
# These charts are based on Figure 8.1 on pg. 188 (multi-bar chart). Simpler charts rendered for capstone project development purposes.
