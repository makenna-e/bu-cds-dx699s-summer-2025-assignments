# %% [markdown]
# **Exploratory Data Analysis and Preprocessing:**

# %%
import pandas as pd

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# Credit Card Fraud Detection Dataset

# %%
df_fraud = pd.read_csv("Fraud_Detection_Data_Train_sampled.csv")

# %%
df_fraud.head()
# Out:
#         id trans_date_trans_time            cc_num  \
# 0  1045211   2020-03-09 15:09:26      577588686219
# 1   547406   2019-08-22 15:49:01    30376238035123
# 2   110142   2019-03-04 01:34:16  4658490815480264
# 3  1285953   2020-06-16 20:04:38  3514897282719543
# 4   271705   2019-05-14 05:54:48  6011381817520024
#
#                                       merchant        category    amt  \
# 0                              fraud_Towne LLC        misc_pos 194.51
# 1                            fraud_Friesen Ltd  health_fitness  52.32
# 2                               fraud_Mohr Inc    shopping_pos   6.53
# 3                      fraud_Gaylord-Powlowski            home   7.33
# 4  fraud_Christiansen, Goyette and Schamberger   gas_transport  64.29
#
#      first        last gender                        street  ...   lat  \
# 0    James  Strickland      M            25454 Leonard Lake  ... 40.62
# 1  Cynthia       Davis      F            7177 Steven Forges  ... 42.83
# ...

# %%
df_fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     80000 non-null  int64
#  1   trans_date_trans_time  80000 non-null  object
#  2   cc_num                 80000 non-null  int64
#  3   merchant               80000 non-null  object
#  4   category               80000 non-null  object
#  5   amt                    80000 non-null  float64
#  6   first                  80000 non-null  object
#  7   last                   80000 non-null  object
#  8   gender                 80000 non-null  object
#  9   street                 80000 non-null  object
#  10  city                   80000 non-null  object
#  11  state                  80000 non-null  object
#  12  zip                    80000 non-null  int64
#  13  lat                    80000 non-null  float64
# ...

# %%
df_fraud.describe()
# Out:
#               id                 cc_num      amt      zip      lat     long  \
# count   80000.00               80000.00 80000.00 80000.00 80000.00 80000.00
# mean   649574.34  411941818557399936.00    70.26 48849.95    38.54   -90.27
# std    373533.62 1301582875556646912.00   139.81 26881.54     5.05    13.72
# min        13.00         60416207185.00     1.00  1257.00    20.03  -165.67
# 25%    326268.25     180040027502291.00     9.62 26237.00    34.67   -96.81
# 50%    649711.00    3519607465576254.00    47.67 48174.00    39.35   -87.59
# 75%    972883.50    4642255475285942.00    82.87 72042.00    41.94   -80.18
# max   1296673.00 4992346398065154048.00  6880.74 99783.00    66.69   -67.95
#
#         city_pop     unix_time  merch_lat  merch_long  is_fraud
# count   80000.00      80000.00   80000.00    80000.00  80000.00
# mean    89477.44 1349287703.54      38.54      -90.27      0.01
# std    307418.00   12810348.11       5.09       13.73      0.08
# ...

# %%
df_fraud_dups = df_fraud[df_fraud.duplicated()]
print(df_fraud_dups)
# Out:
# Empty DataFrame
# Columns: [id, trans_date_trans_time, cc_num, merchant, category, amt, first, last, gender, street, city, state, zip, lat, long, city_pop, job, dob, trans_num, unix_time, merch_lat, merch_long, is_fraud]
# Index: []
#
# [0 rows x 23 columns]

# %%
null_rows = df_fraud[df_fraud.isnull().any(axis=1)]
print(null_rows)
# Out:
# Empty DataFrame
# Columns: [id, trans_date_trans_time, cc_num, merchant, category, amt, first, last, gender, street, city, state, zip, lat, long, city_pop, job, dob, trans_num, unix_time, merch_lat, merch_long, is_fraud]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_fraud.rename(columns={"Unnamed: 0": "id"}, inplace=True)

# %%
df_fraud["id"] = df_fraud["id"].astype(str)

# %%
df_fraud.head()
# Out:
#         id trans_date_trans_time            cc_num  \
# 0  1045211   2020-03-09 15:09:26      577588686219
# 1   547406   2019-08-22 15:49:01    30376238035123
# 2   110142   2019-03-04 01:34:16  4658490815480264
# 3  1285953   2020-06-16 20:04:38  3514897282719543
# 4   271705   2019-05-14 05:54:48  6011381817520024
#
#                                       merchant        category    amt  \
# 0                              fraud_Towne LLC        misc_pos 194.51
# 1                            fraud_Friesen Ltd  health_fitness  52.32
# 2                               fraud_Mohr Inc    shopping_pos   6.53
# 3                      fraud_Gaylord-Powlowski            home   7.33
# 4  fraud_Christiansen, Goyette and Schamberger   gas_transport  64.29
#
#      first        last gender                        street  ...   lat  \
# 0    James  Strickland      M            25454 Leonard Lake  ... 40.62
# 1  Cynthia       Davis      F            7177 Steven Forges  ... 42.83
# ...

# %%
df_fraud.to_csv("Fraud_Detection_Data_Train_sampled.csv", index=False)

# %% [markdown]
# Credit Card Approval Prediction Dataset

# %%
df_credit = pd.read_csv("Credit_Card_Application_Data.csv")

# %%
df_credit.head()
# Out:
#    Applicant_ID Applicant_Gender  Owned_Car  Owned_Realty  Total_Children  \
# 0       5008806          M                1             1               0
# 1       5008808          F                0             1               0
# 2       5008809          F                0             1               0
# 3       5008810          F                0             1               0
# 4       5008811          F                0             1               0
#
#    Total_Income                                        Income_Type  \
# 0        112500  Working                                       ...
# 1        270000  Commercial associate                          ...
# 2        270000  Commercial associate                          ...
# 3        270000  Commercial associate                          ...
# 4        270000  Commercial associate                          ...
#
#                                       Education_Type  \
# 0  Secondary / secondary special                 ...
# ...

# %%
df_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25128 entries, 0 to 25127
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Applicant_ID          25128 non-null  int64
#  1   Applicant_Gender      25128 non-null  object
#  2   Owned_Car             25128 non-null  int64
#  3   Owned_Realty          25128 non-null  int64
#  4   Total_Children        25128 non-null  int64
#  5   Total_Income          25128 non-null  int64
#  6   Income_Type           25128 non-null  object
#  7   Education_Type        25128 non-null  object
#  8   Family_Status         25128 non-null  object
#  9   Housing_Type          25128 non-null  object
#  10  Owned_Mobile_Phone    25128 non-null  int64
#  11  Owned_Work_Phone      25128 non-null  int64
#  12  Owned_Phone           25128 non-null  int64
#  13  Owned_Email           25128 non-null  int64
#  14  Job_Title             25128 non-null  object
# ...

# %%
df_credit.describe()
# Out:
#        Applicant_ID  Owned_Car  Owned_Realty  Total_Children  Total_Income  \
# count      25128.00   25128.00      25128.00        25128.00      25128.00
# mean     5078835.48       0.42          0.65            0.51     194836.50
# std        41943.78       0.49          0.48            0.76     104521.12
# min      5008806.00       0.00          0.00            0.00      27000.00
# 25%      5042225.75       0.00          0.00            0.00     135000.00
# 50%      5079004.00       0.00          1.00            0.00     180000.00
# 75%      5115603.25       1.00          1.00            1.00     225000.00
# max      5150487.00       1.00          1.00            5.00    1575000.00
#
#        Owned_Mobile_Phone  Owned_Work_Phone  Owned_Phone  Owned_Email  \
# count            25128.00          25128.00     25128.00     25128.00
# mean                 1.00              0.27         0.29         0.10
# std                  0.00              0.45         0.46         0.30
# ...

# %%
df_credit_dups = df_credit[df_credit.duplicated()]
print(df_credit_dups)
# Out:
# Empty DataFrame
# Columns: [Applicant_ID, Applicant_Gender, Owned_Car, Owned_Realty, Total_Children, Total_Income, Income_Type, Education_Type, Family_Status, Housing_Type, Owned_Mobile_Phone, Owned_Work_Phone, Owned_Phone, Owned_Email, Job_Title, Total_Family_Members, Applicant_Age, Years_of_Working, Total_Bad_Debt, Total_Good_Debt, Status]
# Index: []
#
# [0 rows x 21 columns]

# %%
null_rows = df_credit[df_credit.isnull().any(axis=1)]
print(null_rows)
# Out:
# Empty DataFrame
# Columns: [Applicant_ID, Applicant_Gender, Owned_Car, Owned_Realty, Total_Children, Total_Income, Income_Type, Education_Type, Family_Status, Housing_Type, Owned_Mobile_Phone, Owned_Work_Phone, Owned_Phone, Owned_Email, Job_Title, Total_Family_Members, Applicant_Age, Years_of_Working, Total_Bad_Debt, Total_Good_Debt, Status]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_credit["Applicant_ID"] = df_credit["Applicant_ID"].astype(str)

# %%
df_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25128 entries, 0 to 25127
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Applicant_ID          25128 non-null  object
#  1   Applicant_Gender      25128 non-null  object
#  2   Owned_Car             25128 non-null  int64
#  3   Owned_Realty          25128 non-null  int64
#  4   Total_Children        25128 non-null  int64
#  5   Total_Income          25128 non-null  int64
#  6   Income_Type           25128 non-null  object
#  7   Education_Type        25128 non-null  object
#  8   Family_Status         25128 non-null  object
#  9   Housing_Type          25128 non-null  object
#  10  Owned_Mobile_Phone    25128 non-null  int64
#  11  Owned_Work_Phone      25128 non-null  int64
#  12  Owned_Phone           25128 non-null  int64
#  13  Owned_Email           25128 non-null  int64
#  14  Job_Title             25128 non-null  object
# ...

# %%
df_credit.to_csv("Credit_Card_Application_Data.csv", index=False)

# %% [markdown]
# Loan Default Prediction Dataset

# %%
df_loan = pd.read_csv("Loan_Default_Data_Train.csv")

# %%
df_loan.head()
# Out:
#        ID  Asst_Reg GGGrade Experience       Validation  Yearly_Income  \
# 0   95074    421802      II     >10yrs            Vfied      633600.00
# 1  134131   3964312      IV       7yrs  Source Verified       85483.20
# 2   92602   4247560     III       <1yr  Source Verified       79200.00
# 3   22591    197179     III       <1yr            Vfied       61600.00
# 4  125060   4646684       V       2yrs  Source Verified       68053.92
#
#   Home_Status  Unpaid_2_years  Already_Defaulted       Designation  ...  \
# 0    MORTGAGE               0                  0   GLENDALE NISSAN  ...
# 1        RENT               0                  0  Business Teacher  ...
# 2        RENT               0                  0            driver  ...
# 3        RENT               0                  0          AvePoint  ...
# 4        RENT               0                  0       Lead Tester  ...
#
#    File_Status       State  Account_Open  Total_Unpaid_CL  Duration  \
# ...

# %%
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87500 entries, 0 to 87499
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   87500 non-null  int64
#  1   Asst_Reg             87500 non-null  int64
#  2   GGGrade              87500 non-null  object
#  3   Experience           87500 non-null  object
#  4   Validation           87500 non-null  object
#  5   Yearly_Income        81925 non-null  float64
#  6   Home_Status          87500 non-null  object
#  7   Unpaid_2_years       87500 non-null  int64
#  8   Already_Defaulted    87500 non-null  int64
#  9   Designation          86086 non-null  object
#  10  Debt_to_Income       84011 non-null  float64
#  11  Postal_Code          86111 non-null  float64
#  12  Lend_Amount          87500 non-null  float64
#  13  Deprecatory_Records  87500 non-null  int64
#  14  Interest_Charged     87500 non-null  float64
# ...

# %%
df_loan.describe()
# Out:
#              ID   Asst_Reg  Yearly_Income  Unpaid_2_years  Already_Defaulted  \
# count  87500.00   87500.00       81925.00        87500.00           87500.00
# mean   83946.25 3798914.12      134859.63            0.33               0.01
# std    36100.10 2289038.08       98824.73            0.88               0.08
# min    21560.00   24847.00        8800.00            0.00               0.00
# 25%    52616.75 1483874.25       83246.59            0.00               0.00
# 50%    83900.00 4132010.50      114400.00            0.00               0.00
# 75%   115261.25 5952908.75      160160.00            0.00               0.00
# max   146559.00 7351847.00     8264030.72           18.00               6.00
#
#        Debt_to_Income  Postal_Code  Lend_Amount  Deprecatory_Records  \
# count        84011.00     86111.00     87500.00             87500.00
# mean            30.94     51155.39     25920.54                 0.20
# ...

# %%
df_loan_dups = df_loan[df_loan.duplicated()]
print(df_loan_dups)
# Out:
# Empty DataFrame
# Columns: [ID, Asst_Reg, GGGrade, Experience, Validation, Yearly_Income, Home_Status, Unpaid_2_years, Already_Defaulted, Designation, Debt_to_Income, Postal_Code, Lend_Amount, Deprecatory_Records, Interest_Charged, Usage_Rate, Inquiries, Present_Balance, Gross_Collection, Sub_GGGrade, File_Status, State, Account_Open, Total_Unpaid_CL, Duration, Unpaid_Amount, Reason, Claim_Type, Due_Fee, Default]
# Index: []
#
# [0 rows x 30 columns]

# %%
null_rows = df_loan[df_loan.isnull().any(axis=1)]
print(null_rows)
# Out:
#            ID  Asst_Reg GGGrade Experience       Validation  Yearly_Income  \
# 7       94448   1468916     III       4yrs  Source Verified            NaN
# 8      109853   7067902     VII       <1yr            Vfied            NaN
# 9      138407   2704860      II       2yrs        Not Vfied      149600.00
# 12      58608    372846     III     >10yrs            Vfied      144320.00
# 15      76507    874224       I     >10yrs        Not Vfied       91520.00
# ...       ...       ...     ...        ...              ...            ...
# 87483  143101   3878048       V       8yrs  Source Verified      130240.00
# 87490   93393    859824      II       1yrs  Source Verified      112640.00
# 87492   66652   7073160      II     >10yrs        Not Vfied            NaN
# 87493  136044   5884961       I       9yrs  Source Verified      392480.00
# 87499  104968   6637289     III       2yrs            Vfied            NaN
#
#       Home_Status  Unpaid_2_years  Already_Defaulted  \
# ...

# %%
df_loan = df_loan.dropna()

# %%
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68505 entries, 0 to 87498
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   68505 non-null  int64
#  1   Asst_Reg             68505 non-null  int64
#  2   GGGrade              68505 non-null  object
#  3   Experience           68505 non-null  object
#  4   Validation           68505 non-null  object
#  5   Yearly_Income        68505 non-null  float64
#  6   Home_Status          68505 non-null  object
#  7   Unpaid_2_years       68505 non-null  int64
#  8   Already_Defaulted    68505 non-null  int64
#  9   Designation          68505 non-null  object
#  10  Debt_to_Income       68505 non-null  float64
#  11  Postal_Code          68505 non-null  float64
#  12  Lend_Amount          68505 non-null  float64
#  13  Deprecatory_Records  68505 non-null  int64
#  14  Interest_Charged     68505 non-null  float64
# ...

# %%
df_loan["Postal_Code"] = df_loan["Postal_Code"].astype(str)

# %%
df_loan["ID"] = df_loan["ID"].astype(str)

# %%
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68505 entries, 0 to 87498
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   68505 non-null  object
#  1   Asst_Reg             68505 non-null  int64
#  2   GGGrade              68505 non-null  object
#  3   Experience           68505 non-null  object
#  4   Validation           68505 non-null  object
#  5   Yearly_Income        68505 non-null  float64
#  6   Home_Status          68505 non-null  object
#  7   Unpaid_2_years       68505 non-null  int64
#  8   Already_Defaulted    68505 non-null  int64
#  9   Designation          68505 non-null  object
#  10  Debt_to_Income       68505 non-null  float64
#  11  Postal_Code          68505 non-null  object
#  12  Lend_Amount          68505 non-null  float64
#  13  Deprecatory_Records  68505 non-null  int64
#  14  Interest_Charged     68505 non-null  float64
# ...

# %%
df_loan.to_csv("Loan_Default_Data_Train.csv", index=False)
